# %%
#Membuat program untuk menentukan di hari apa restoran paling banyak menyelesaikan orderan

# %%
#1. Import library and dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
PATH_DATA='../data/'

# %%
df=pd.read_csv(PATH_DATA+'food_delivery_datasets.csv')

# %%
#2. Declare the variables

# %%
df
# Out:
#         order_id  voucher_amount                   date_time  eta_seconds  \
# 0     FOOD-10455               0  2018-08-12T20:35:08.001006         1800
# 1     FOOD-10985               0  2018-09-23T17:44:12.243273         2173
# 2     FOOD-10911               0  2018-09-19T18:08:09.387991         1418
# 3     FOOD-10932               0  2018-09-21T01:24:35.272499         1903
# 4     FOOD-10961               0  2018-09-22T17:57:45.523161         1716
# ...          ...             ...                         ...          ...
# 1071  FOOD-10921               0  2018-09-20T15:01:52.152828          900
# 1072  FOOD-10265            5000  2018-07-26T14:43:23.655294         1579
# 1073  FOOD-10534               0  2018-08-21T20:10:59.283185         2606
# 1074  FOOD-10158               0  2018-07-16T14:42:23.214427         2428
# 1075  FOOD-10770               0  2018-09-11T14:18:19.494258         1547
#
#       food_price  cust_id  rating  delivery_fee   resto_id     status  \
# ...

# %%
df['date_time']=pd.to_datetime(df['date_time']).dt.round('H')
df['date_time']
# Out:
# 0      2018-08-12 21:00:00
# 1      2018-09-23 18:00:00
# 2      2018-09-19 18:00:00
# 3      2018-09-21 01:00:00
# 4      2018-09-22 18:00:00
#                ...
# 1071   2018-09-20 15:00:00
# 1072   2018-07-26 15:00:00
# 1073   2018-08-21 20:00:00
# 1074   2018-07-16 15:00:00
# 1075   2018-09-11 14:00:00
# Name: date_time, Length: 1076, dtype: datetime64[ns]

# %%
x=df[['resto_id','status']]
x.head()
# Out:
#     resto_id     status
# 0  742638033  Completed
# 1  742767245  Completed
# 2  742618303  Completed
# 3  742541172  Completed
# 4  742604875  Completed

# %%
y=df['date_time'].dt.strftime('%A')
y
# Out:
# 0          Sunday
# 1          Sunday
# 2       Wednesday
# 3          Friday
# 4        Saturday
#           ...
# 1071     Thursday
# 1072     Thursday
# 1073      Tuesday
# 1074       Monday
# 1075      Tuesday
# Name: date_time, Length: 1076, dtype: object

# %%
df=pd.concat([a['resto_id'],b,a['status']], axis=1)
df.columns=['resto_id','days','status']
df.sample(10)
# Out:
#       resto_id       days     status
# 500  742718214     Friday  Completed
# 181  742538073   Saturday  Cancelled
# 197  742724283     Friday  Cancelled
# 100  742684501   Thursday  Cancelled
# 92   742598967     Sunday  Cancelled
# 37   742538372    Tuesday  Completed
# 430  742740172     Friday  Completed
# 517  742554548     Monday  Cancelled
# 595  742764517     Friday  Completed
# 216  742560850  Wednesday  Completed

# %%
#3. Clean the dataset with status completed only

# %%
group_status=df.groupby('status')
group_status['status'].size()
# Out:
# status
# Cancelled    195
# Completed    881
# Name: status, dtype: int64

# %%
df=df[df.status=='Completed']
df.reset_index(drop=True)
# Out:
#       resto_id       days     status
# 0    742638033     Sunday  Completed
# 1    742767245     Sunday  Completed
# 2    742618303  Wednesday  Completed
# 3    742541172     Friday  Completed
# 4    742604875   Saturday  Completed
# ..         ...        ...        ...
# 876  742742150   Thursday  Completed
# 877  742566851   Thursday  Completed
# 878  742571888    Tuesday  Completed
# 879  742725064     Monday  Completed
# 880  742594499    Tuesday  Completed
#
# [881 rows x 3 columns]

# %%
#4. Visualize the data

# %%
days=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df.groupby(['days']).size().reindex(days)
# Out:
# days
# Monday       102
# Tuesday      114
# Wednesday    106
# Thursday     106
# Friday       123
# Saturday     149
# Sunday       181
# dtype: int64

# %%
#Dapat terlihat dari data, bahwa reestoran paling banyak mendapatkan pesanan di hari libur (Sabtu dan Minggu)
